# %% [markdown]
# <a href="https://colab.research.google.com/github/tejaswiniram20/cb2330-portfolio/blob/main/Formula.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
counts = [
    3473, 2876, 2480, 2445, 1524, 1980, 1237, 3635, 2060, 2386,
    2562, 2109, 1915, 2189, 3094, 1974, 2407, 2653, 2374, 1940,
    1871, 2456, 2140, 2207, 4757, 2882, 3834, 2512, 1663, 2023,
    1222, 591, 2266, 985, 2432, 3248, 2132, 1292, 2490, 3251,
    1979, 2000, 1736, 2612, 2411, 2283, 1324, 1948, 2084, 3840,
    2375, 2223, 2069, 973, 2088, 2541, 6317, 1918, 3863, 1647,
]
print("Harmonic mean is the average for rates")
def sum(counts):
    total=0
    reci=0
    for count in counts:
        total+=1/count
    return total

def harmonic_mean(counts):
  return len(counts)/sum(counts)

print(harmonic_mean(counts))
# Out:
# Harmonic mean is the average for rates
# 2038.2134693113453
